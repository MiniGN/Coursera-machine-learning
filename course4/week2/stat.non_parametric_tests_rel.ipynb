# %% [markdown]
# # Непараметрические криетрии

# %% [markdown]
#   Критерий | Одновыборочный | Двухвыборочный | Двухвыборочный (связанные выборки)
#   ------------- | -------------|
#   **Знаков**  | $\times$ | | $\times$
#   **Ранговый** | $\times$  | $\times$ | $\times$
#   **Перестановочный** | $\times$  | $\times$ | $\times$

# %% [markdown]
# ## Терапия при анорексии

# %% [markdown]
# В исследовании оценивается эффективность поведенческой терапии для лечения анорексии. Для 50 пациентов известен вес до начала терапии и по её окончании. Была ли терапия эффективной?

# %%
import numpy as np
import pandas as pd
import itertools

from scipy import stats
from statsmodels.stats.descriptivestats import sign_test
from statsmodels.stats.weightstats import zconfint

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Загрузка данных

# %%
weight_data = pd.read_csv('weight.txt', sep = '\t', header = 0)

# %%
weight_data.head()
# Out:
#    Before  After
# 0    80.5   82.2
# 1    84.9   85.6
# 2    81.5   81.4
# 3    82.6   81.9
# 4    79.9   76.4

# %%
pylab.figure(figsize=(12,4))

pylab.subplot(1,2,1)
pylab.grid()
pylab.hist(weight_data.Before, color = 'r')
pylab.xlabel('Before')

pylab.subplot(1,2,2)
pylab.grid()
pylab.hist(weight_data.After, color = 'b')
pylab.xlabel('After')

pylab.show()

# %%
weight_data.describe()
# Out:
#           Before       After
# count  29.000000   29.000000
# mean   82.689655   85.696552
# std     4.845495    8.351924
# min    70.000000   71.300000
# 25%    80.400000   81.900000
# 50%    82.600000   83.900000
# 75%    85.000000   90.900000
# max    94.900000  103.600000

# %% [markdown]
# ## Двухвыборочные критерии для связных выборок

# %% [markdown]
# $H_0\colon$ медианы веса до и после терапии совпадает
#
# $H_1\colon$ медианы веса до и после тепрапии отличаются

# %%
print ('95%% confidence interval for mean weight before therapy: [%f, %f]' % zconfint(weight_data.Before))
# Out:
# 95% confidence interval for mean weight before therapy: [80.926107, 84.453203]

# %%
print ('95%% confidence interval for mean weight after therapy: [%f, %f]' % zconfint(weight_data.After))
# Out:
# 95% confidence interval for mean weight after therapy: [82.656817, 88.736286]

# %%
pylab.hist(weight_data.After - weight_data.Before)
pylab.show()

# %% [markdown]
# ### Критерий знаков

# %% [markdown]
# $H_0\colon P\left(X_1>X_2\right)=\frac1{2},$
#
# $H_1\colon P\left(X_1>X_2\right)\neq\frac1{2}$

# %%
print ("M: %d, p-value: %f" % sign_test(weight_data.After - weight_data.Before))
# Out:
# M: 3, p-value: 0.264931

# %% [markdown]
# ### Критерий знаковых рангов Уилкоксона

# %% [markdown]
# $H_0\colon med\left(X_1-X_2\right)=0,$
#
# $H_1\colon med\left(X_1-X_2\right)\neq0$

# %%
stats.wilcoxon(weight_data.After, weight_data.Before)
# Out:
# WilcoxonResult(statistic=131.5, pvalue=0.062919722626026672)

# %%
stats.wilcoxon(weight_data.After - weight_data.Before)
# Out:
# WilcoxonResult(statistic=131.5, pvalue=0.062919722626026672)

# %% [markdown]
# ### Перестановочный критерий

# %% [markdown]
# $H_0\colon \mathbb{E}(X_1 - X_2) = 0$
#
# $H_1\colon \mathbb{E}(X_1 - X_2) \neq 0$

# %%
def f1(x,mean):
    return x - mean
    
def permutation_t_stat_1sample(sample, mean):
    t_stat = sum(map(f1(mean), sample))
    return t_stat

# %%
def permutation_zero_distr_1sample(sample, mean, max_permutations = None):
    centered_sample = map(lambda x:(x - mean), sample)
    if max_permutations:
        signs_array = set([tuple(x) for x in 2 * np.random.randint(2, size = (max_permutations, 
                                                                              len(sample))) - 1 ])
    else:
        signs_array =  itertools.product([-1, 1], repeat = len(sample))
    distr = [sum(centered_sample * np.array(signs)) for signs in signs_array]
    return distr

# %%
pylab.hist(permutation_zero_distr_1sample(weight_data.After - weight_data.Before, 0., 
                               max_permutations = 10000))
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-03456440e33e> in <module>()
#       1 pylab.hist(permutation_zero_distr_1sample(weight_data.After - weight_data.Before, 0.,
# ----> 2                                max_permutations = 10000))
#       3 pylab.show()
#
# <ipython-input-37-d397ae68b274> in permutation_zero_distr_1sample(sample, mean, max_permutations)
#       7     else:
#       8         signs_array =  itertools.product([-1, 1], repeat = len(sample))
# ----> 9     distr = [sum(centered_sample * np.array(signs)) for signs in signs_array]
#      10     return distr
#
# <ipython-input-37-d397ae68b274> in <listcomp>(.0)
#       7     else:
#       8         signs_array =  itertools.product([-1, 1], repeat = len(sample))
# ----> 9     distr = [sum(centered_sample * np.array(signs)) for signs in signs_array]
#      10     return distr
#
# TypeError: unsupported operand type(s) for *: 'map' and 'int'

# %%
def permutation_test(sample, mean, max_permutations = None, alternative = 'two-sided'):
    if alternative not in ('two-sided', 'less', 'greater'):
        raise ValueError("alternative not recognized\n"
                         "should be 'two-sided', 'less' or 'greater'")
    
    t_stat = permutation_t_stat_1sample(sample, mean)
    
    zero_distr = permutation_zero_distr_1sample(sample, mean, max_permutations)
    
    if alternative == 'two-sided':
        return sum([1. if abs(x) >= abs(t_stat) else 0. for x in zero_distr]) / len(zero_distr)
    
    if alternative == 'less':
        return sum([1. if x <= t_stat else 0. for x in zero_distr]) / len(zero_distr)

    if alternative == 'greater':
        return sum([1. if x >= t_stat else 0. for x in zero_distr]) / len(zero_distr)

# %%
print ("p-value: %f" % permutation_test(weight_data.After - weight_data.Before, 0., 
                               max_permutations = 1000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5203e984aa0d> in <module>()
#       1 print ("p-value: %f" % permutation_test(weight_data.After - weight_data.Before, 0.,
# ----> 2                                max_permutations = 1000))
#
# <ipython-input-25-712a7e2e01e3> in permutation_test(sample, mean, max_permutations, alternative)
#       6     t_stat = permutation_t_stat_1sample(sample, mean)
#       7
# ----> 8     zero_distr = permutation_zero_distr_1sample(sample, mean, max_permutations)
#       9
#      10     if alternative == 'two-sided':
#
# <ipython-input-23-96a9a9a09fac> in permutation_zero_distr_1sample(sample, mean, max_permutations)
#       6     else:
#       7         signs_array =  itertools.product([-1, 1], repeat = len(sample))
# ----> 8     distr = [sum(centered_sample * np.array(signs)) for signs in signs_array]
#       9     return distr
#
# <ipython-input-23-96a9a9a09fac> in <listcomp>(.0)
#       6     else:
#       7         signs_array =  itertools.product([-1, 1], repeat = len(sample))
# ----> 8     distr = [sum(centered_sample * np.array(signs)) for signs in signs_array]
#       9     return distr
#
# TypeError: unsupported operand type(s) for *: 'map' and 'int'

# %%
print ("p-value: %f" % permutation_test(weight_data.After - weight_data.Before, 0., 
                               max_permutations = 50000))
